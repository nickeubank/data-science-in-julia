# %% [markdown]
# # National Income and Infant Mortality
#
# In this Jupyter Notebook, we'll analyze the relationship between a country's GDP per capita (a measure of average income per person) and infant mortality (in particular, the share of every 1,000 children born who do not reach their fifth birthday).

# %% [markdown]
# ## Data
#
# Data for this analysis comes from the World Bank's *World Development Indicators* database.

# %%
import pandas as pd
import numpy as np

# Download World Development Indicators
wdi = pd.read_csv("https://media.githubusercontent.com/media/nickeubank/MIDS_Data/master/World_Development_Indicators/wdi_small.csv")

# %% [markdown]
# The data is currently one row per country-indicator:

# %%
wdi.head()
# Out:
#    Unnamed: 0 Country Name Country Code  \
# 0       75203  Afghanistan          AFG
# 1       75242  Afghanistan          AFG
# 2       75279  Afghanistan          AFG
# 3       75302  Afghanistan          AFG
# 4       75395  Afghanistan          AFG
#
#                                       Indicator Name  Indicator Code     1960  \
# 0  Adolescent fertility rate (births per 1,000 wo...     SP.ADO.TFRT  145.245
# 1  Antiretroviral therapy coverage for PMTCT (% o...  SH.HIV.PMTC.ZS      NaN
# 2           Battle-related deaths (number of people)     VC.BTL.DETH      NaN
# 3  Cause of death, by communicable diseases and m...  SH.DTH.COMM.ZS      NaN
# 4  Completeness of infant death reporting (% of r...  SP.DTH.INFR.ZS      NaN
#
#       1961     1962     1963     1964  ...       2010       2011      2012  \
# 0  145.245  145.245  145.245  145.245  ...    98.6322    92.3776    86.123
# 1      NaN      NaN      NaN      NaN  ...        NaN        NaN       NaN
# 2      NaN      NaN      NaN      NaN  ...  6864.0000  7405.0000  7719.000
# 3      NaN      NaN      NaN      NaN  ...    50.2000        NaN       NaN
# 4      NaN      NaN      NaN      NaN  ...        NaN        NaN       NaN
#
#         2013        2014        2015        2016       2017  2018  Unnamed: 63
# 0    81.7908     77.4586     73.1264     68.7942     64.462   NaN          NaN
# 1        NaN         NaN         NaN         NaN        NaN   NaN          NaN
# 2  8056.0000  12285.0000  17273.0000  17981.0000  18950.000   NaN          NaN
# 3        NaN         NaN     40.6000     36.4000        NaN   NaN          NaN
# 4        NaN         NaN         NaN         NaN        NaN   NaN          NaN
#
# [5 rows x 65 columns]

# %% [markdown]
# We would much rather have each country be its own row, and we only care about 2015, so let's re-organize our data.
#
# First, we can drop all the extra years:

# %%
wdi = wdi[['Country Name', 'Country Code', 'Indicator Name', 
           'Indicator Code', '2015']]
wdi.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                       Indicator Name  Indicator Code  \
# 0  Adolescent fertility rate (births per 1,000 wo...     SP.ADO.TFRT
# 1  Antiretroviral therapy coverage for PMTCT (% o...  SH.HIV.PMTC.ZS
# 2           Battle-related deaths (number of people)     VC.BTL.DETH
# 3  Cause of death, by communicable diseases and m...  SH.DTH.COMM.ZS
# 4  Completeness of infant death reporting (% of r...  SP.DTH.INFR.ZS
#
#          2015
# 0     73.1264
# 1         NaN
# 2  17273.0000
# 3     40.6000
# 4         NaN

# %%
wdi = wdi.pivot(index='Country Name', columns='Indicator Name', values='2015')
wdi = wdi.reset_index()
wdi.head()
# Out:
# Indicator Name    Country Name  \
# 0                  Afghanistan
# 1                      Albania
# 2                      Algeria
# 3               American Samoa
# 4                      Andorra
#
# Indicator Name  Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                                         73.1264
# 1                                                         20.6922
# 2                                                         10.7052
# 3                                                             NaN
# 4                                                             NaN
#
# Indicator Name  Antiretroviral therapy coverage for PMTCT (% of pregnant women living with HIV)  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                            28.0
# 3                                                             NaN
# 4                                                             NaN
#
# Indicator Name  Battle-related deaths (number of people)  \
# 0                                                17273.0
# 1                                                    NaN
# 2                                                  110.0
# 3                                                    NaN
# 4                                                    NaN
#
# Indicator Name  CPIA building human resources rating (1=low to 6=high)  \
# 0                                                             3.5
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
# Indicator Name  CPIA business regulatory environment rating (1=low to 6=high)  \
# 0                                                             2.5
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
# Indicator Name  CPIA debt policy rating (1=low to 6=high)  \
# 0                                                     3.0
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#
# Indicator Name  CPIA economic management cluster average (1=low to 6=high)  \
# 0                                                             3.0
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
# Indicator Name  CPIA efficiency of revenue mobilization rating (1=low to 6=high)  \
# 0                                                             3.0
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
# Indicator Name  CPIA equity of public resource use rating (1=low to 6=high)  \
# 0                                                             3.0
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
# Indicator Name  ...  \
# 0               ...
# 1               ...
# 2               ...
# 3               ...
# 4               ...
#
# Indicator Name  Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)  \
# 0                                                            32.6
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
# Indicator Name  Women who believe a husband is justified in beating his wife (any of five reasons) (%)  \
# 0                                                            80.2
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
# Indicator Name  Women who believe a husband is justified in beating his wife when she argues with him (%)  \
# 0                                                            59.2
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
# Indicator Name  Women who believe a husband is justified in beating his wife when she burns the food (%)  \
# 0                                                            18.2
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
# Indicator Name  Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                            66.9
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
# Indicator Name  Women who believe a husband is justified in beating his wife when she neglects the children (%)  \
# 0                                                            48.4
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
# Indicator Name  Women who believe a husband is justified in beating his wife when she refuses sex with him (%)  \
# 0                                                            33.4
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
# Indicator Name  Women who were first married by age 15 (% of women ages 20-24)  \
# 0                                                             8.8
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
# Indicator Name  Women who were first married by age 18 (% of women ages 20-24)  \
# 0                                                            34.8
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
# Indicator Name  Women's share of population ages 15+ living with HIV (%)
# 0                                                             NaN
# 1                                                            30.3
# 2                                                            44.8
# 3                                                             NaN
# 4                                                             NaN
#
# [5 rows x 129 columns]

# %% [markdown]
# Now each row is a country, and we have all the variables we want to potentially analyze.

# %% [markdown]
# # Visualizing the Relationship between Log GDP Per Capita and Infant Mortality
#
# [Now it's your turn! insert the plot from `analyze_health_and_income.py` here and make any required changes to make it work]

# %% [markdown]
# # Learning from Outliers
#
# While we are often interested in overall trends, exceptions to a trend can sometimes be just as interesting.
#
# Suppose you are an analyst asked to advise the goverment of Mozambique (which has a Log GDP Per Capita of about 6.25) on how it could reduce it's child mortality, but you don't know where to being. One option is to look for other countries whose income level is similar to that of Mozambique, but who have lower mortality levels.
#
# Re-make the plot from above, but this time including only countries with income levels similar to that of Mozambique. Then below the plot, create a markdown cell in which you explain what countries you might research and why.

# %% [markdown]
# # Export and Send Your Notebook to Me!
#
# When you are finished, put your names in the top cell and export your notebook as both a Python Notebook (so it's file name ends in `.ipynb`) and as a PDF and email them to me at [nick@nickeubank.com](mailto:nick@nickeubank.com).
